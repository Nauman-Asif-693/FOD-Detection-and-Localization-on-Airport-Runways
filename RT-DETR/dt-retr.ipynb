# %%
from ultralytics import RTDETR

# Load a COCO-pretrained RT-DETR-l model
model = RTDETR("rtdetr-l.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/home/ahabb/Downloads/fod-a/FullDatasetV.2.1-400x400/fod_dataset.yaml", 
    epochs=10, 
    imgsz=400,
    name='dt-retr_fod_10',     # Name of the training run
    project='dt-retr_10_epochs')
# Out:
# ...
# 100%|██████████| 63.4M/63.4M [00:27<00:00, 2.41MB/s]
# rt-detr-l summary: 673 layers, 32,970,476 parameters, 0 gradients, 108.3 GFLOPs
# New https://pypi.org/project/ultralytics/8.3.3 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.4 torch-2.4.1 CUDA:0 (NVIDIA RTX A2000 12GB, 12024MiB)
# ...

# %%
from ultralytics import RTDETR

# Load a COCO-pretrained RT-DETR-l model
model = RTDETR("rtdetr-l.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/home/ahabb/Downloads/fod-a/FullDatasetV.2.1-400x400/fod_dataset.yaml", 
    epochs=50, 
    imgsz=400,
    name='dt-retr_fod_50',     # Name of the training run
    project='dt-retr_50_epochs')
# Out:
# rt-detr-l summary: 673 layers, 32,970,476 parameters, 0 gradients, 108.3 GFLOPs
# New https://pypi.org/project/ultralytics/8.3.3 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.99 🚀 Python-3.12.4 torch-2.4.1 CUDA:0 (NVIDIA RTX A2000 12GB, 12024MiB)
# ...
